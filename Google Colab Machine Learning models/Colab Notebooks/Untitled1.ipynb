# %%
print("hello world")

# %%
def add(a,b):
  print(a+b)

add(2,2)
# Out:
# 4

# %%
print(max(76,98,9,10,67,251,34,))
import pandas
type(pandas)
# Out:
# 251
# module

# %%
import pandas as pd
series = pd.Series(data=None, index=None, dtype=None, name=None)
# Out:
# <ipython-input-8-664a135262b2>:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   series = pd.Series(data=None, index=None, dtype=None, name=None)
