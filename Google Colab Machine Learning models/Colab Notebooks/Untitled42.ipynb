# %%
import pandas as pd

import googleapiclient.discovery

# %%
API_KEY = "AIzaSyC9fPgtcENQKJsMjVc8Wi41PmBtgK_m_o8"

# %%
pip install --upgrade google-api-python-client

# %%
    API_SERVICE_NAME = "youtube"
    API_VERSION = "v3"

# %%
VIDEO_ID = "rfscVS0vtbw"

# %%
    youtube = googleapiclient.discovery.build(
        API_SERVICE_NAME, API_VERSION, developerKey = API_KEY)

    request = youtube.commentThreads().list(
        part="snippet,replies",
        maxResults=100,
        videoId=VIDEO_ID
    )
    response = request.execute()

# %%
len(response['items'])
# Out:
# 20

# %%
response['items']
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'ulv_tSRLDgMNYyqekaEI0TjGHfc',
#   'id': 'Ugxqcek3RUzxWv-4VqB4AaABAg',
#   'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#    'videoId': 'rfscVS0vtbw',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '4o2Fw93WN0igobHsFPJKTa4BNP4',
#     'id': 'Ugxqcek3RUzxWv-4VqB4AaABAg',
#     'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#      'videoId': 'rfscVS0vtbw',
#      'textDisplay': 'Want more from Mike? He&#39;s starting a coding RPG/Bootcamp - <a href="https://simulator.dev/">https://simulator.dev/</a>',
#      'textOriginal': "Want more from Mike? He's starting a coding RPG/Bootcamp - https://simulator.dev/",
#      'authorDisplayName': 'freeCodeCamp.org',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKaqca-xQcJtp1Pqv-APucCa0nToHYGPVT00YBGOSw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC8butISFwT-Wl7EV0hUK0BQ',
# ...

# %%
response['items'][0]['snippet']
# Out:
# {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#  'videoId': 'rfscVS0vtbw',
#  'topLevelComment': {'kind': 'youtube#comment',
#   'etag': '4o2Fw93WN0igobHsFPJKTa4BNP4',
#   'id': 'Ugxqcek3RUzxWv-4VqB4AaABAg',
#   'snippet': {'channelId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#    'videoId': 'rfscVS0vtbw',
#    'textDisplay': 'Want more from Mike? He&#39;s starting a coding RPG/Bootcamp - <a href="https://simulator.dev/">https://simulator.dev/</a>',
#    'textOriginal': "Want more from Mike? He's starting a coding RPG/Bootcamp - https://simulator.dev/",
#    'authorDisplayName': 'freeCodeCamp.org',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKaqca-xQcJtp1Pqv-APucCa0nToHYGPVT00YBGOSw=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UC8butISFwT-Wl7EV0hUK0BQ',
#    'authorChannelId': {'value': 'UC8butISFwT-Wl7EV0hUK0BQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 3876,
#    'publishedAt': '2021-03-09T18:41:00Z',
# ...

# %%
#top levels commands

response['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal']
# Out:
# "Want more from Mike? He's starting a coding RPG/Bootcamp - https://simulator.dev/"

# %%
df = pd.json_normalize(response['items'])

# %%
df.columns = df.columns.str.removeprefix('snippet.topLevelComment.').str.removeprefix('snippet.')

# %%
df.to_csv(f'comments-{VIDEO_ID}.csv',index = False)

# %% [markdown]
# # New Section
