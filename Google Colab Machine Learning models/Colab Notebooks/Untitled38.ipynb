# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


titanic_data = pd.read_csv('/content/sample_data/titanic.csv')
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#Overall Survval rate of passngers on the titanic 

sbn.catplot(x ="Survived" ,kind ="count", data = titanic_data)

# %%
#Gender distibution amoung the Passangers

titanic_data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sbn.catplot(x ="Sex" ,kind ="count", data = titanic_data)

# %%
#Survial differ from gender 

titanic_data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
sns.catplot(x ="Sex", hue ="Survived",
kind ="count", data = titanic_data)

# %%
#Age distribution passngers amount titanic

titanic_data['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
sns.violinplot(x ="Age", hue ="Survived",
data = titanic_data, split = True)

#20-40 age groups are high.
# Out:
# <Axes: xlabel='Age'>

# %%
#surviull rate differ by journey class?how much?
