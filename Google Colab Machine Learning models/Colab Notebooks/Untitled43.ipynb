# %%
pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.3 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=f2a0c592e8e62896d960ea413c66bb6ecd091ea3947beb4f56a92280fae6759a
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
import random
import pandas as pd
import sklearn.matrics.pairwise
import cosine_similarity
import tourch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-cfe7b3342c27> in <cell line: 3>()
#       1 import random
#       2 import pandas as pd
# ----> 3 import sklearn.matrics.pairwise
#       4 import cosine_similarity
#       5 import tourch
#
# ModuleNotFoundError: No module named 'sklearn.matrics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
file_path = {"AI interview sample dataset.xlsx"}
df  = pd.read_excel(file_path)

term_dict = pd.Series(df.Defintion.valueindex.df.Term).to_dict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3b4aa5a37c3b> in <cell line: 2>()
#       1 file_path = {"AI interview sample dataset.xlsx"}
# ----> 2 df  = pd.read_excel(file_path)
#       3
#       4 term_dict = pd.Series(df.Defintion.valueindex.df.Term).to_dict()
#
# NameError: name 'pd' is not defined

# %%
for index,value in terms_dict.items():
  print(f"Term: {index}, Definition: {value}")

# %%
#load model
model_name = "bert-base-nli-mean-token"
model = sentence_transformers(model_name)

#Create a Function

# %%
random.seed(42)

random_term = random_choice(list(term_dict.keys()))
answer = term_dict(random_term)
print(f"please describe {random_term}")
user_input = input("Your Answer: ")

# %%
answer_voc = encode(answer)
unsr_input_voc = encode(user_input).unsqueeze(0)
answer_voc
user_input_voc

# %%
similarity = cosine_similarity(answer_voc,user_input_voc)

print(f"Answer {answer}")
print(f"Cousine similiaity : {similairty[0][0]}")

# %% [markdown]
# # New Section
