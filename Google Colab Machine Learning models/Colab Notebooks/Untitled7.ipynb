# %%
import pandas  as pd

from sklearn import preprocessing

dataset = pd.read_csv('/content/sample_data/detailed_data.csv')
dataset.head()

dataset['college name'].value_counts()

label_encode = LabelEncoder

labels = label_encode.fit_transform(dataset.collegename)

label['collegename'] = labels

dataset.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-02e876b9b279> in <cell line: 12>()
#      10 label_encode = LabelEncoder
#      11
# ---> 12 labels = label_encode.fit_transform(dataset.collegename)
#      13
#      14 label['collegename'] = labels
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'collegename'
