# %%
#salary prediction 
import pandas as pd

dataset = pd.read_csv('/content/sample_data/Salary_dataset.csv')
dataset
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes

# %%
dataset.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
dataset['YearsExperience'] = dataset['YearsExperience'].astype("int64")

# %%
dataset.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0                1  39344.0
# 1           1                1  46206.0
# 2           2                1  37732.0
# 3           3                2  43526.0
# 4           4                2  39892.0

# %%
import seaborn as sns

sns.countplot(x = 'Salary',data = dataset )
# Out:
# <Axes: xlabel='Salary', ylabel='count'>

# %%
dataset['YearsExperience'] = dataset['YearsExperience'].astype("int64")



x = dataset.drop(columns = 'Salary',axis = 1)
y = dataset['Salary']

print(x)
print(y)
# Out:
#     Unnamed: 0  YearsExperience
# 0            0                1
# 1            1                1
# 2            2                1
# 3            3                2
# 4            4                2
# 5            5                3
# 6            6                3
# 7            7                3
# 8            8                3
# 9            9                3
# 10          10                4
# 11          11                4
# 12          12                4
# 13          13                4
# 14          14                4
# 15          15                5
# 16          16                5
# 17          17                5
# 18          18                6
# 19          19                6
# 20          20                6
# 21          21                7
# 22          22                8
# 23          23                8
# 24          24                8
# 25          25                9
# 26          26                9
# 27          27                9
# ...

# %%
dataset.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0                1  39344.0
# 1           1                1  46206.0
# 2           2                1  37732.0
# 3           3                2  43526.0
# 4           4                2  39892.0

# %%
#train test model

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 3)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24, 2)
# (6, 2)
# (24,)
# (6,)

# %%
#create a model 

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()


model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
#prediction 

x_train_prediction  = model.predict(x_train)

#accuracy 
x_train_accuracy = accuracy_score(x_train_prediction,y_train)
print('The X_Train_Accuracy Was : ',x_train_accuracy)
# Out:
# The X_Train_Accuracy Was :  0.4166666666666667

# %%
#prediction
x_test_prediction  = model.predict(x_test)

#accuracy 
x_test_accuracy = accuracy_score(x_test_prediction,y_test)

print('The X_Test_Accuracy Was : ' ,x_test_accuracy)
# Out:
# The X_Test_Accuracy Was :  0.0

# %%
model.predict([[0,1]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([39344.])
